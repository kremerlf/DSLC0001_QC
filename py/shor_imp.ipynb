# %%
from Shor import shor

# %%
shor(8)
# Out:
# '8 is even'

# %%
shor(17)
# Out:
# '17 is a prime'

# %%
shor(25)
# Out:
# '25 is a n**x'

# %%
shor(15)
# Out:
# [5, 3]

# %%
for i in range(10):
    print(f'factors: {shor(357)}')
# Out:
# factors: [17, 21]
# factors: [17, 21]
# factors: [17, 21]
# factors: [17, 21]
# factors: [17, 21]
# factors: [3, 119]
# factors: [21, 17]
# factors: [21, 17]
# factors: [3, 119]
# factors: [17, 21]

# %%
for i in range(10):
    print(f'factors: {shor(45)}')
# Out:
# factors: [9, 5]
# factors: [3, 15]
# factors: [3, 15]
# factors: [5, 9]
# factors: [3, 15]
# factors: [9, 5]
# factors: [3, 15]
# factors: None
# factors: [5, 9]
# factors: [9, 5]

# %%
for i in range(10):
    print(f'factors: {shor(21)}')
# Out:
# factors: [3, 7]
# factors: [7, 3]
# factors: [3, 7]
# factors: [3, 7]
# factors: [7, 3]
# factors: None
# factors: None
# factors: [3, 7]
# factors: [3, 7]
# factors: None
